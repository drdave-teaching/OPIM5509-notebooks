# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="100%" alt="OPIM 5509 banner"/>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drdave-teaching/OPIM5509-notebooks/blob/main/Module1/4_General_EDA_Template.ipynb)

# %% [markdown]
# # Module 1.4 - General EDA Template
#
# **OPIM 5509: Introduction to Deep Learning - University of Connecticut**
#
# A blank worksheet, not a lecture. Every heading below is a step you will repeat on every dataset for the rest of this course and the rest of your career.
#
# Fill in the blanks from memory. **Type the code, do not paste it** - your fingers need to learn the syntax, and they only learn it by moving.
#
# You will not need every section on every dataset. You will need all of them eventually.
#
# **On your own:** keep a copy of this in your Drive. When the final project lands and you are staring at an unfamiliar file, this is the page you open first.

# %% [markdown]
# ## 1. Import modules and read the data
# Set up your environment. Prefer a stable public URL over a Drive mount - your notebook should run on anyone's machine.

# %%
# import your libraries here


# read your data here

# %% [markdown]
# ## 2. Shape, column names, data types, missing values
# What are you working with? Any missing values? Wrong data types? Values that cannot be true?
#
# If there are missing values you can (a) delete the rows, or (b) impute - a constant like 0 or -999, the column mean or median, forward fill, backfill, interpolation. Every choice is a decision you should be able to defend.

# %%
# .shape, .columns, .dtypes, .info(), .isnull().sum()

# %% [markdown]
# ## 3. What is a row?
# Write it in one plain sentence. If you cannot, you are not ready to model.

# %%
# .head() - then say it out loud

# %% [markdown]
# ## 4. Statistics and percentiles
# More granularity on the numeric columns. Any suspicious minimums or maximums? Any ceiling the data was capped at? Any binary variable hiding as a float?

# %%
# .describe(), .quantile([...]), .mean(), .median(), .mode()

# %% [markdown]
# ## 5. Flag / dummy / indicator variables
# Recode something continuous into a 0 or a 1 so you can subset and compare groups.

# %%
# np.where(condition, 1, 0)

# %% [markdown]
# ## 6. Subsetting rows and columns
# Extra columns you do not need? Rows that are not really observations - subtotals, blanks, summary lines? Drop them, and know why.

# %%
# .drop(), .loc[], .iloc[], boolean masks

# %% [markdown]
# ## 7. Group by (pivot tables)
# Count, min, max, mean, standard deviation - split by a category and compare.

# %%
# .groupby('col')[['a','b']].mean()

# %% [markdown]
# ## 8. Correlation
# How do the numeric columns relate to each other and to your target? Watch for two columns carrying the same information.

# %%
# .corr(numeric_only=True) and a seaborn heatmap

# %% [markdown]
# ## 9. Univariate plots
# Histograms, boxplots, kernel density plots. One variable at a time.

# %%
# .hist(), plt.boxplot(), sns.kdeplot()

# %% [markdown]
# ## 10. Bivariate plots
# Scatterplots, and scatterplots colored by a third variable. Label every axis.

# %%
# plt.scatter(x, y) - with a title and axis labels

# %% [markdown]
# ## 11. Write down what you found
# Three to five sentences, quantitative, in plain language. This is the part that gets graded and the part that gets you hired.

# %%
# no code - just write it in a markdown cell

# %% [markdown]
# 🔷 **The nugget:** EDA is not a phase you finish. You come back to it every time a model does something you did not expect.
